# %%
# ==========================================
# Project
# ==========================================

PROJECT_NAME = "Precipitation Downscaling Khulna"

print(PROJECT_NAME)
# Out:
# Precipitation Downscaling Khulna

# %%
from pathlib import Path
import yaml
import os

import numpy as np
import pandas as pd

import rasterio
import geopandas as gpd

# %%
from pathlib import Path
import yaml

# Project Root
PROJECT_ROOT = Path(
    r"E:\Geospatial\Precipitation Downscaling\Precipitation-Downscaling-Khulna"
)

print(PROJECT_ROOT)
# Out:
# E:\Geospatial\Precipitation Downscaling\Precipitation-Downscaling-Khulna

# %%
# Load environment.yml

with open(PROJECT_ROOT / "environment.yml", "r", encoding="utf-8") as file:
    config = yaml.safe_load(file)

print("Configuration Loaded Successfully")
# Out:
# Configuration Loaded Successfully

# %%
# Define Paths

RAW_DATA = PROJECT_ROOT / config["paths"]["raw_data"]
PROCESSED_DATA = PROJECT_ROOT / config["paths"]["processed_data"]
INTERIM_DATA = PROJECT_ROOT / config["paths"]["interim_data"]
OUTPUT_DATA = PROJECT_ROOT / config["paths"]["output_data"]

print("Raw Data:", RAW_DATA)
print("Output:", OUTPUT_DATA)
# Out:
# Raw Data: E:\Geospatial\Precipitation Downscaling\Precipitation-Downscaling-Khulna\data\Raw
# Output: E:\Geospatial\Precipitation Downscaling\Precipitation-Downscaling-Khulna\data\output

# %%
MAPS = PROJECT_ROOT / "data" / "MAPS"

print("MAPS:", MAPS)
print("Exists:", MAPS.exists())
# Out:
# MAPS: E:\Geospatial\Precipitation Downscaling\Precipitation-Downscaling-Khulna\data\MAPS
# Exists: True

# %%
MAPS = PROJECT_ROOT / config["results"]["maps"]

print("MAPS:", MAPS)
print("Exists:", MAPS.exists())
# Out:
# MAPS: E:\Geospatial\Precipitation Downscaling\Precipitation-Downscaling-Khulna\data\MAPS
# Exists: True
